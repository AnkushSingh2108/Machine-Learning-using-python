# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
# %matplotlib notebook

# %%
X,y = make_regression(n_samples=1000, n_features=2,n_informative=2,noise=10)
X.shape,y.shape
# Out:
# ((1000, 2), (1000,))

# %%
plt.subplot(1,2,1)
plt.scatter(X[:,0],y)

plt.subplot(1,2,2)
plt.scatter(X[:,1],y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from mpl_toolkits import mplot3d

fig = plt.figure(figsize = (10,7))
ax = plt.axes(projection = '3d')

# Creating Plot
ax.scatter3D(X[:,0], X[:,1], y, color = "blue")
plt.title("3D Scatter Plot")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Implementing Linear Regression ising sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.coef_ # this gives the coefficient "ax+by+c=0"
# Out:
# array([56.85993051, 48.5424391 ])

# %%
model.intercept_ # this gives theta0 or the value of c in "ax+by+c=0"
# Out:
# -0.28122032706998334

# %%
model.predict([X[0],X[1]])  #this gives the predictions i.e. y values for X[0] abd X[1]
# Out:
# array([-51.77541416,  67.81030701])

# %%
y[0],y[1]
# Out:
# (-57.3362570698076, 66.8813072100806)

# %%
model.score(X,y)
# Out:
# 0.98112045123849
