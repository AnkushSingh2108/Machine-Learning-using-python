# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = np.linspace(0.0,6.0)
y1 = np.sin(2*np.pi*x1)
x2 = np.linspace(0.0,6.0)
y2  = np.sin(2*np.pi*x2)

# %%
# plt.subplot(2,1,1)
# plt.plot(x3,y3,"--")
# plt.xlabel("X-axis")
# plt.ylabel("Y-axis")
# plt.title("Khudse bnaya hua Sine Graph", color = "magenta")

# %%
plt.subplot(2,1,1)
plt.plot(x1,y1,"--")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Sine Graph", color = "magenta")
# Out:
# Text(0.5, 1.0, 'Sine Graph')

# %%
plt.subplot(2,1,2)
plt.plot(x2,y2,":")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Cosine Graph")
plt.grid()
plt.show()

# %%
x3 = np.linspace(0.0,6.0)
y3 = np.sin(2*np.pi*x3) * np.exp(-x3)
plt.subplot()
plt.plot(x3,y3,"o-")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Cosine Graph")
plt.grid()
plt.show()
