# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  #this module is used for 3D plotting
import numpy as np
# %matplotlib notebook
#because of this only in jupyter notebook we can rotate the 3D plot

# %%
# print(dir(np))

# %%
X = np.arange(-5,5,0.25)
Y = np.arange(-5,5,0.25)
X,Y = np.meshgrid(X,Y)
R = np.sqrt(X**2 + Y**2)
S = np.sqrt(X**5 + Y**5)
Z = np.exp(R)
A = np.exp(-R)
D = np.exp(S)
F = np.exp(-S)
# Out:
# c:\users\ankush\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in sqrt
#   """

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X,Y,Z, rstride = 1, cstride = 2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X,Y,A, rstride = 1, cstride = 2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X,Y,D, rstride = 1, cstride = 2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# c:\users\ankush\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X,Y,F, rstride = 1, cstride = 2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# c:\users\ankush\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   This is separate from the ipykernel package so we can avoid doing imports until
