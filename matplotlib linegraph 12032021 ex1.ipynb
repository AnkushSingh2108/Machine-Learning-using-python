# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,56,4,6,4]
y = [2,1,58,63,418,6,45,45]

# %%
plt.plot(x,y)
plt.show()

# %%
a = [1,2,3,4,5,6,7,8,9]
b = [2,5,7,8,1,4,9,8,7]
plt.plot(a,b)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("This is my first graph in matplotlib at 12032021")
plt.show()
